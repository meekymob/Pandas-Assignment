# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('flights-2.csv')

# %%
df
# Out:
#        MONTH  DAY  WEEKDAY AIRLINE ORG_AIR DEST_AIR  SCHED_DEP  DEP_DELAY  \
# 0          1    1        4      WN     LAX      SLC       1625       58.0
# 1          1    1        4      UA     DEN      IAD        823        7.0
# 2          1    1        4      MQ     DFW      VPS       1305       36.0
# 3          1    1        4      AA     DFW      DCA       1555        7.0
# 4          1    1        4      WN     LAX      MCI       1720       48.0
# ...      ...  ...      ...     ...     ...      ...        ...        ...
# 58487     12   31        4      AA     SFO      DFW        515        5.0
# 58488     12   31        4      F9     LAS      SFO       1910       13.0
# 58489     12   31        4      OO     SFO      SBA       1846       -6.0
# 58490     12   31        4      WN     MSP      ATL        525       39.0
# 58491     12   31        4      OO     SFO      BOI        859        5.0
#
#        AIR_TIME  DIST  SCHED_ARR  ARR_DELAY  DIVERTED  CANCELLED
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 58492 entries, 0 to 58491
# Data columns (total 14 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   MONTH      58492 non-null  int64
#  1   DAY        58492 non-null  int64
#  2   WEEKDAY    58492 non-null  int64
#  3   AIRLINE    58492 non-null  object
#  4   ORG_AIR    58492 non-null  object
#  5   DEST_AIR   58492 non-null  object
#  6   SCHED_DEP  58492 non-null  int64
#  7   DEP_DELAY  57659 non-null  float64
#  8   AIR_TIME   57474 non-null  float64
#  9   DIST       58492 non-null  int64
#  10  SCHED_ARR  58492 non-null  int64
#  11  ARR_DELAY  57474 non-null  float64
#  12  DIVERTED   58492 non-null  int64
#  13  CANCELLED  58492 non-null  int64
# dtypes: float64(3), int64(8), object(3)
# memory usage: 6.2+ MB

# %%
df.describe()
# Out:
#               MONTH           DAY       WEEKDAY     SCHED_DEP     DEP_DELAY  \
# count  58492.000000  58492.000000  58492.000000  58492.000000  57659.000000
# mean       6.220646     15.702096      3.926862   1387.984836     10.921192
# std        3.358484      8.760846      1.995777    482.810792     36.146210
# min        1.000000      1.000000      1.000000      5.000000    -24.000000
# 25%        3.000000      8.000000      2.000000   1000.000000     -4.000000
# 50%        6.000000     16.000000      4.000000   1353.000000     -1.000000
# 75%        9.000000     23.000000      6.000000   1805.000000     10.000000
# max       12.000000     31.000000      7.000000   2359.000000   1194.000000
#
#            AIR_TIME          DIST     SCHED_ARR     ARR_DELAY      DIVERTED  \
# count  57474.000000  58492.000000  58492.000000  57474.000000  58492.000000
# mean     115.928576    872.900072   1549.399832      5.812315      0.002342
# ...

# %%
#Question 1

# %%
# Find the number of cancelled flight for every airline per day

# %%
airline_per_day = df.groupby(['DAY','AIRLINE']).agg({"CANCELLED":"sum"}).sort_values(by='DAY').rename(columns={"CANCELLED":"Cancelled_Airline"})

# %%
airline_per_day
# Out:
#              Cancelled_Airline
# DAY AIRLINE
# 1   AA                      11
#     WN                       2
#     VX                       1
#     US                       3
#     UA                       6
# ...                        ...
# 31  AS                       0
#     AA                       2
#     VX                       0
#     F9                       0
#     WN                       0
#
# [432 rows x 1 columns]

# %%
# Reset the index

# %%
airlines = airline_per_day.reset_index()

# %%
airlines
# Out:
#      DAY AIRLINE  Cancelled_Airline
# 0      1      AA                 11
# 1      1      WN                  2
# 2      1      VX                  1
# 3      1      US                  3
# 4      1      UA                  6
# ..   ...     ...                ...
# 427   31      AS                  0
# 428   31      AA                  2
# 429   31      VX                  0
# 430   31      F9                  0
# 431   31      WN                  0
#
# [432 rows x 3 columns]

# %%
# Question 2

# %%
## Finding the number of cancelled and diverted airlines

# %%
cancelled_diverted_flight = df.groupby(['WEEKDAY','AIRLINE']).agg({"CANCELLED":"sum","DIVERTED": "sum"}).reset_index()

# %%
cancelled_diverted_flight
# Out:
#     WEEKDAY AIRLINE  CANCELLED  DIVERTED
# 0         1      AA         41         6
# 1         1      AS          0         0
# 2         1      B6          0         0
# 3         1      DL         10         2
# 4         1      EV         30         3
# ..      ...     ...        ...       ...
# 93        7      OO         29         3
# 94        7      UA         14         4
# 95        7      US          6         0
# 96        7      VX          2         1
# 97        7      WN          7         3
#
# [98 rows x 4 columns]

# %%
#Converting to Dataframe

# %%
cancelled_diverted_flight = pd.DataFrame(cancelled_diverted_flight)

# %%
# Percentage of Cancelled

# %%
cancelled_diverted_flight['Percentage_of_Cancelled']=round((cancelled_diverted_flight['CANCELLED']/cancelled_diverted_flight['CANCELLED'].sum())*100,2)

# %%
# Percentage of Diverted

# %%
cancelled_diverted_flight['Percentage_of_DIVERTED']=round((cancelled_diverted_flight['DIVERTED']/cancelled_diverted_flight['DIVERTED'].sum())*100,2)

# %%
# The number and the percentage of cancelled and diverted airlines

# %%
cancelled_diverted_flight
# Out:
#     WEEKDAY AIRLINE  CANCELLED  DIVERTED  Percentage_of_Cancelled  \
# 0         1      AA         41         6                     4.65
# 1         1      AS          0         0                     0.00
# 2         1      B6          0         0                     0.00
# 3         1      DL         10         2                     1.14
# 4         1      EV         30         3                     3.41
# ..      ...     ...        ...       ...                      ...
# 93        7      OO         29         3                     3.29
# 94        7      UA         14         4                     1.59
# 95        7      US          6         0                     0.68
# 96        7      VX          2         1                     0.23
# 97        7      WN          7         3                     0.79
#
#     Percentage_of_DIVERTED
# 0                     4.38
# 1                     0.00
# 2                     0.00
# 3                     1.46
# 4                     2.19
# ...

# %%
# Question 3

# %%
df['Airtime'] = df['AIR_TIME']

# %%
origin_destination_flight = df.groupby(['ORG_AIR','DEST_AIR']).agg({"AIRLINE":"count","CANCELLED":"count","AIR_TIME":"mean","Airtime":"var"}).reset_index().rename(columns={"AIR_TIME":"Airtime_Average","Airtime":"Airtime_Variance"})

# %%
flight_details = pd.DataFrame(origin_destination_flight)

# %%
flight_details['Flight_Percentage'] = round(flight_details['AIRLINE']/flight_details['AIRLINE'].sum()*100,2)

# %%
flight_details
# Out:
#      ORG_AIR DEST_AIR  AIRLINE  CANCELLED  Airtime_Average  Airtime_Variance  \
# 0        ATL      ABE       31         31        96.387097         45.778495
# 1        ATL      ABQ       16         16       170.500000         87.866667
# 2        ATL      ABY       19         19        28.578947          6.590643
# 3        ATL      ACY        6          6        91.333333         11.466667
# 4        ATL      AEX       40         40        78.725000         47.332692
# ...      ...      ...      ...        ...              ...               ...
# 1125     SFO      SNA      122        122        64.059322         11.338331
# 1126     SFO      STL       20         20       198.900000        101.042105
# 1127     SFO      SUN       10         10        78.000000         25.777778
# 1128     SFO      TUS       20         20       100.200000         35.221053
# 1129     SFO      XNA        2          2       173.500000          0.500000
#
#       Flight_Percentage
# ...

# %%
## Loading the second dataset

# %%
covid = pd.read_csv('covid_subset-1.txt')

# %%
covid.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 36 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   iso_code                         205 non-null    object
#  1   continent                        205 non-null    object
#  2   location                         205 non-null    object
#  3   date                             205 non-null    object
#  4   total_cases                      205 non-null    float64
#  5   new_cases                        205 non-null    float64
#  6   total_deaths                     205 non-null    float64
#  7   new_deaths                       205 non-null    float64
#  8   total_cases_per_million          205 non-null    float64
#  9   new_cases_per_million            205 non-null    float64
#  10  total_deaths_per_million         205 non-null    float64
#  11  new_deaths_per_million           205 non-null    float64
# ...

# %%
## Load Covid dataset

# %%
covid
# Out:
#     iso_code continent     location        date  total_cases  new_cases  \
# 0        AFG      Asia  Afghanistan  2019-12-31          0.0        0.0
# 1        AFG      Asia  Afghanistan  2020-01-01          0.0        0.0
# 2        AFG      Asia  Afghanistan  2020-01-02          0.0        0.0
# 3        AFG      Asia  Afghanistan  2020-01-03          0.0        0.0
# 4        AFG      Asia  Afghanistan  2020-01-04          0.0        0.0
# ..       ...       ...          ...         ...          ...        ...
# 200      AFG      Asia  Afghanistan  2020-07-28      36368.0      105.0
# 201      AFG      Asia  Afghanistan  2020-07-29      36471.0      103.0
# 202      AFG      Asia  Afghanistan  2020-07-30      36471.0        0.0
# 203      AFG      Asia  Afghanistan  2020-07-31      36542.0       71.0
# 204      AFG      Asia  Afghanistan  2020-08-01      36710.0      168.0
#
#      total_deaths  new_deaths  total_cases_per_million  new_cases_per_million  \
# ...

# %%
## Finding the dimension of the dataset

# %%
covid.shape
# Out:
# (205, 36)

# %%
new_covid = pd.DataFrame(covid[['continent', 'location','total_cases','total_deaths','gdp_per_capita','tests_per_case',
                               'life_expectancy','female_smokers','male_smokers','diabetes_prevalence']])

# %%
new_covid
# Out:
#     continent     location  total_cases  total_deaths  gdp_per_capita  \
# 0        Asia  Afghanistan          0.0           0.0        1803.987
# 1        Asia  Afghanistan          0.0           0.0        1803.987
# 2        Asia  Afghanistan          0.0           0.0        1803.987
# 3        Asia  Afghanistan          0.0           0.0        1803.987
# 4        Asia  Afghanistan          0.0           0.0        1803.987
# ..        ...          ...          ...           ...             ...
# 200      Asia  Afghanistan      36368.0        1270.0        1803.987
# 201      Asia  Afghanistan      36471.0        1271.0        1803.987
# 202      Asia  Afghanistan      36471.0        1271.0        1803.987
# 203      Asia  Afghanistan      36542.0        1271.0        1803.987
# 204      Asia  Afghanistan      36710.0        1283.0        1803.987
#
#      tests_per_case  life_expectancy  female_smokers  male_smokers  \
# ...

# %%
## Finding the missing values

# %%
new_covid.isnull().sum()
# Out:
# continent                0
# location                 0
# total_cases              0
# total_deaths             0
# gdp_per_capita           0
# tests_per_case         205
# life_expectancy          0
# female_smokers         205
# male_smokers           205
# diabetes_prevalence      0
# dtype: int64

# %%
## tests_per_case, female_smoker and male_smoker all have 205 missing values respectively

# %% [markdown]
# # Data cleaning for missing values

# %%
#Checking missing value in tests_per_case variable

# %%
new_covid[new_covid['tests_per_case'].isnull()]
# Out:
#     continent     location  total_cases  total_deaths  gdp_per_capita  \
# 0        Asia  Afghanistan          0.0           0.0        1803.987
# 1        Asia  Afghanistan          0.0           0.0        1803.987
# 2        Asia  Afghanistan          0.0           0.0        1803.987
# 3        Asia  Afghanistan          0.0           0.0        1803.987
# 4        Asia  Afghanistan          0.0           0.0        1803.987
# ..        ...          ...          ...           ...             ...
# 200      Asia  Afghanistan      36368.0        1270.0        1803.987
# 201      Asia  Afghanistan      36471.0        1271.0        1803.987
# 202      Asia  Afghanistan      36471.0        1271.0        1803.987
# 203      Asia  Afghanistan      36542.0        1271.0        1803.987
# 204      Asia  Afghanistan      36710.0        1283.0        1803.987
#
#      tests_per_case  life_expectancy  female_smokers  male_smokers  \
# ...

# %%
new_covid['tests_per_case'].value_counts()
# Out:
# Series([], Name: tests_per_case, dtype: int64)

# %%
new_covid['female_smokers'].value_counts()
# Out:
# Series([], Name: female_smokers, dtype: int64)

# %%
new_covid['male_smokers'].value_counts()
# Out:
# Series([], Name: male_smokers, dtype: int64)

# %%
# Since all missing values in each of the variables have no value and no relationship with other variables,
# i will drop the columns to prevent overfitting

# %%
new_covid.drop(columns=['tests_per_case','female_smokers','male_smokers'], axis=1, inplace=True)

# %%
new_covid
# Out:
#     continent     location  total_cases  total_deaths  gdp_per_capita  \
# 0        Asia  Afghanistan          0.0           0.0        1803.987
# 1        Asia  Afghanistan          0.0           0.0        1803.987
# 2        Asia  Afghanistan          0.0           0.0        1803.987
# 3        Asia  Afghanistan          0.0           0.0        1803.987
# 4        Asia  Afghanistan          0.0           0.0        1803.987
# ..        ...          ...          ...           ...             ...
# 200      Asia  Afghanistan      36368.0        1270.0        1803.987
# 201      Asia  Afghanistan      36471.0        1271.0        1803.987
# 202      Asia  Afghanistan      36471.0        1271.0        1803.987
# 203      Asia  Afghanistan      36542.0        1271.0        1803.987
# 204      Asia  Afghanistan      36710.0        1283.0        1803.987
#
#      life_expectancy  diabetes_prevalence
# 0              64.83                 9.59
# ...

# %%
# Finding continent with the highest total cases and total death of corona virus

# %%
continent_by_cases_death = new_covid.groupby('continent').agg({"total_cases":"max","total_deaths":"count"}).reset_index()

# %%
continent_by_cases_death
# Out:
#   continent  total_cases  total_deaths
# 0      Asia      36710.0           205

# %%
# Country with the highest number of death

# %%
country_covid_highest_death = new_covid.groupby('location').agg({"total_deaths":"max"}).reset_index()

# %%
country_covid_highest_death
# Out:
#       location  total_deaths
# 0  Afghanistan        1283.0

# %%
# Country with the highest death and total cases

# %%
country_covid_cases_highest_death = new_covid.groupby(['continent']).agg({"total_deaths":"max","total_cases":"sum"}).reset_index()

# %%
country_covid_cases_highest_death
# Out:
#   continent  total_deaths  total_cases
# 0      Asia        1283.0    2083662.0
